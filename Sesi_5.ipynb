# %% [markdown]
# # Python for Data Science // S.5 // Pandas Introduction // PYTN-KS09
# ---

# %%
import numpy as np
import pandas as pd

# %%
# read from url
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')
# melihat 5 baris pertama
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# melihat 5 baris terakhir
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
# melihat banyak data dan shape
print(len(df))
print(df.shape)
# Out:
# 126314
# (126314, 23)

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %% [markdown]
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
len(df)
# Out:
# 126314

# %%
df.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df.type
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 126314

# %%
df.shape
# Out:
# (126314, 23)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
pd.set_option("display.precision", 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe(include = 'O')
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     194611010TRH     NBA  4/13/2011     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           L  at New York NY
# freq           63138       63157             440

# %%
df.describe(include = ['int', 'object'])
# Out:
#         gameorder       game_id   lg_id   _iscopy    year_id  date_game  \
# count   126314.00        126314  126314  126314.0  126314.00     126314
# unique        NaN         63157       2       NaN        NaN      12426
# top           NaN  194611010TRH     NBA       NaN        NaN  4/13/2011
# freq          NaN             2  118016       NaN        NaN         30
# mean     31579.00           NaN     NaN       0.5    1988.20        NaN
# std      18231.93           NaN     NaN       0.5      17.58        NaN
# min          1.00           NaN     NaN       0.0    1947.00        NaN
# 25%      15790.00           NaN     NaN       0.0    1975.00        NaN
# 50%      31579.00           NaN     NaN       0.5    1990.00        NaN
# 75%      47368.00           NaN     NaN       1.0    2003.00        NaN
# max      63157.00           NaN     NaN       1.0    2015.00        NaN
#
#         seasongame  is_playoffs team_id fran_id        pts  opp_id opp_fran  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df[['team_id', 'fran_id' ]].value_counts()
# Out:
# team_id  fran_id
# BOS      Celtics    5997
# NYK      Knicks     5769
# LAL      Lakers     5078
# DET      Pistons    4985
# PHI      Sixers     4533
#                     ...
# TRH      Huskies      60
# DTF      Falcons      60
# PIT      Ironmen      60
# INJ      Jets         60
# SDS      Sails        11
# Length: 104, dtype: int64

# %%
len(df)
# Out:
# 126314

# %%
len(df['team_id'])
# Out:
# 126314

# %%
df['team_id'].shape
# Out:
# (126314,)

# %%
df.isnull().sum()
# Out:
# gameorder             0
# game_id               0
# lg_id                 0
# _iscopy               0
# year_id               0
# date_game             0
# seasongame            0
# is_playoffs           0
# team_id               0
# fran_id               0
# pts                   0
# elo_i                 0
# elo_n                 0
# win_equiv             0
# opp_id                0
# opp_fran              0
# opp_pts               0
# opp_elo_i             0
# opp_elo_n             0
# game_location         0
# game_result           0
# forecast              0
# notes            120890
# dtype: int64

# %%
df.loc[df["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.loc[df["fran_id"] == "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
df.loc[df['team_id'] == 'BOS', 'pts'].sum()
# Out:
# 626484

# %%
kn = pd.DataFrame(np.random.randint(1,10, size=(3,5)), index = [1,2,3], columns = tuple('ABCDE'))

# %%
kn
# Out:
#    A  B  C  D  E
# 1  1  7  7  2  1
# 2  8  1  1  1  9
# 3  9  2  4  9  6

# %%
kn.loc[kn['A'] == 9].sum()
# Out:
# A    9
# B    2
# C    4
# D    9
# E    6
# dtype: int64

# %%
kn[kn['A'] == 9].sum()
# Out:
# A    9
# B    2
# C    4
# D    9
# E    6
# dtype: int64

# %%
akm = pd.read_csv('kapal_titanic.csv')
akm.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 0         0       3    male  22.0      1      0   7.25        S  NaN
# 1         1       1  female  38.0      1      0  71.28        C    C
# 2         1       3  female  26.0      0      0   7.92        S  NaN
# 3         1       1  female  35.0      1      0  53.10        S    C
# 4         0       3    male  35.0      0      0   8.05        S  NaN

# %%
akm.loc[akm['embarked'] == 'S'].sum()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_9296\1231793523.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   akm.loc[akm['embarked'] == 'S'].sum()
# survived                                                  217
# pclass                                                   1514
# sex         malefemalefemalemalemalemalefemalefemalefemale...
# age                                                  16312.75
# sibsp                                                     368
# parch                                                     266
# fare                                                  17439.4
# embarked    SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSS...
# dtype: object

# %%
akm.loc[akm['embarked'] == 'S', 'age'].sum()
# Out:
# 16312.75

# %%
akm.loc[akm['embarked'] == 'S', 'age'].sum()
# Out:
# 16312.75

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
type(revenues)
# Out:
# pandas.core.series.Series

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
revenues2 = pd.Series([5555, 7000, 1980, 1780])

# %%
revenues2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"],
    columns=['A', 'B', 'C']
)
city_revenues
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 city_revenues = pd.Series(
#       2     [4200, 8000, 6500],
#       3     index=["Amsterdam", "Toronto", "Tokyo"],
#       4     columns=['A', 'B', 'C']
#       5 )
#       6 city_revenues
#
# TypeError: __init__() got an unexpected keyword argument 'columns'

# %%
city_revenues = pd.DataFrame(data=np.random.randn(3,3),
    index=["Amsterdam", "Toronto", "Tokyo"],
    columns=['A', 'B', 'C']
)
city_revenues
# Out:
#               A     B     C
# Amsterdam  0.22 -0.34 -0.35
# Toronto   -0.10 -0.96 -0.44
# Tokyo      0.70 -0.05 -0.06

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues.dtypes
# Out:
# dtype('int64')

# %%
city_revenues.ndim
# Out:
# 1

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
city_employee_count.items()

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %%
akm
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 0           0       3    male  22.0      1      0   7.25        S  NaN
# 1           1       1  female  38.0      1      0  71.28        C    C
# 2           1       3  female  26.0      0      0   7.92        S  NaN
# 3           1       1  female  35.0      1      0  53.10        S    C
# 4           0       3    male  35.0      0      0   8.05        S  NaN
# ..        ...     ...     ...   ...    ...    ...    ...      ...  ...
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
akm.loc[akm['embarked'] == 'Q', 'age'].sum()
# Out:
# 786.5

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues,
    "employee_count": city_employee_count
})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
#       1 city_data = pd.DataFrame({
# ----> 2     "revenue": city_revenuess,
#       3     "employee_count": city_employee_countt
#       4 })
#       5 city_data
#
# NameError: name 'city_revenuess' is not defined

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
'Amsterdam' in city_data
# Out:
# False

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
'Tokyo' in city_data
# Out:
# False

# %%
'revenue' in city_data
# Out:
# True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
'_iscopy' in df.keys()
# Out:
# True

# %%
'_iscopyy'in df.keys()
# Out:
# False

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues['Toronto']
# Out:
# 8000

# %%
city_revenues[1]
# Out:
# 8000

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"],
    index=[1, 2, 3, 5, 8]
)

# %%
colors[1]
# Out:
# 'red'

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[-2]
# Out:
# 'green'

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.revenue.to_frame()
# Out:
#            revenue
# Amsterdam     4200
# Tokyo         6500
# Toronto       8000

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])

# %%
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
print('hello \
world!')
# Out:
# hello world!

# %%
toys
# Out:
#                     name            shape
# 0  [ball, 'Rubik's cube]  [spehere, cube]

# %%
toys.ndim
# Out:
# 2

# %%
toys.shape
# Out:
# (1, 2)

# %%
toys
# Out:
#                     name            shape
# 0  [ball, 'Rubik's cube]  [spehere, cube]

# %%
toys
# Out:
#                     name            shape
# 0  [ball, 'Rubik's cube]  [spehere, cube]

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])

# %%
toys.shape
# Out:
# (2, 2)

# %%
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Tokyo": "Toronto"]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1:3]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.iloc[-1]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     1
# year_id                  2015
# date_game           6/16/2015
# seasongame                103
# is_playoffs                 1
# team_id                   GSW
# fran_id              Warriors
# pts                       105
# elo_i                 1813.63
# elo_n                 1822.29
# win_equiv               68.52
# opp_id                    CLE
# opp_fran            Cavaliers
# opp_pts                    97
# opp_elo_i             1700.74
# opp_elo_n             1692.09
# game_location               A
# game_result                 W
# forecast                 0.52
# notes                     NaN
# Name: 126313, dtype: object

# %%
city_data.loc["Amsterdam": "Tokyo", "revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: revenue, dtype: int64

# %%
city_data.dtypes
# Out:
# revenue             int64
# employee_count    float64
# dtype: object

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.loc[5555:5559, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
current_decade = df[df["year_id"] > 2010]

# %%
df[(df["year_id"] > 2010) & (df['team_id'] == 'PHO')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# 113690      56846  201010280UTA   NBA        1     2011  10/28/2010
# 113713      56857  201010290PHO   NBA        0     2011  10/29/2010
# 113779      56890  201011030PHO   NBA        0     2011   11/3/2010
# 113811      56906  201011050PHO   NBA        0     2011   11/5/2010
# ...           ...           ...   ...      ...      ...         ...
# 125999      63000  201504070ATL   NBA        1     2015    4/7/2015
# 126015      63008  201504080DAL   NBA        1     2015    4/8/2015
# 126054      63028  201504100NOP   NBA        1     2015   4/10/2015
# 126091      63046  201504120SAS   NBA        1     2015   4/12/2015
# 126123      63062  201504140PHO   NBA        0     2015   4/14/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 113660           1            0     PHO    Suns   92  1643.02  1630.62
# ...

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
df.notes.isnull().sum()
# Out:
# 120890

# %%
df.notes.notnull().sum()
# Out:
# 5424

# %%
df.notes.notna().sum()
# Out:
# 5424

# %%
df.notes.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: notes
# Non-Null Count  Dtype
# --------------  -----
# 5424 non-null   object
# dtypes: object(1)
# memory usage: 987.0+ KB

# %%
ers = df[df["fran_id"].str.endswith("ers")]

# %%
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
deka1 = df["_iscopy"] == 0
deka2 = df["pts"] > 100
deka3 = df["opp_pts"] > 100
deka4 = df["team_id"] == "BLB"

deka5 = df[deka1 & deka2 & deka3 & deka4]
deka5
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notna())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues[['Amsterdam', 'Toronto']].sum()
# Out:
# 12200

# %%
city_revenues.argmax()
# Out:
# 1

# %%
points = df["pts"]
points.sum()
# Out:
# 12976235

# %%
df['pts'].sum()
# Out:
# 12976235

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
df.groupby("fran_id")["pts"].sum()
# Out:
# fran_id
# Baltimore        37219
# Bombers          17793
# Bucks           418326
# Bulls           437269
# Capitols         22387
# Cavaliers       380416
# Celtics         626484
# Clippers        380523
# Colonels         94435
# Condors          49642
# Denver            4818
# Falcons           3797
# Floridians       49568
# Grizzlies       157683
# Hawks           567261
# Heat            229103
# Hornets          84489
# Huskies           3995
# Ironmen           3674
# Jazz            363155
# Jets              4482
# Kings           569245
# Knicks          582497
# Lakers          637444
# Magic           219436
# Mavericks       309239
# Nets            417809
# Nuggets         445780
# Olympians        22864
# Pacers          438288
# Packers           6193
# Pelicans        220794
# Pistons         572758
# Raptors         158370
# Rebels            4474
# Redskins          5372
# Rockets         432504
# Sails            30080
# Sixers          585891
# ...

# %%
df.groupby("fran_id", sort = False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
deka1 = df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)]

# %%
dekam = deka1.groupby(["year_id", "game_result"])["game_id"].count()

# %%
dekam
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
deka1
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113684      56843  201010270SAS   NBA        0     2011  10/27/2010
# 113733      56867  201010300SAS   NBA        0     2011  10/30/2010
# 113744      56873  201011010LAC   NBA        1     2011   11/1/2010
# 113778      56890  201011030PHO   NBA        1     2011   11/3/2010
# 113824      56913  201011060SAS   NBA        0     2011   11/6/2010
# ...           ...           ...   ...      ...      ...         ...
# 126192      63097  201504240SAS   NBA        0     2015   4/24/2015
# 126209      63105  201504260SAS   NBA        0     2015   4/26/2015
# 126221      63111  201504280LAC   NBA        1     2015   4/28/2015
# 126228      63115  201504300SAS   NBA        0     2015   4/30/2015
# 126233      63117  201505020LAC   NBA        1     2015    5/2/2015
#
#         seasongame  is_playoffs team_id fran_id  pts    elo_i    elo_n  \
# 113684           1            0     SAS   Spurs  122  1594.28  1599.31
# ...

# %%
deka1[deka1['game_result'] == 'L'].count()
# Out:
# gameorder        133
# game_id          133
# lg_id            133
# _iscopy          133
# year_id          133
# date_game        133
# seasongame       133
# is_playoffs      133
# team_id          133
# fran_id          133
# pts              133
# elo_i            133
# elo_n            133
# win_equiv        133
# opp_id           133
# opp_fran         133
# opp_pts          133
# opp_elo_i        133
# opp_elo_n        133
# game_location    133
# game_result      133
# forecast         133
# notes              0
# dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
deka4 = df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)]

# %%
deka4[deka4['game_result'] == 'W']
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 123716      61859  201410290SAC   NBA        1     2015  10/29/2014
# 123751      61876  201411010GSW   NBA        0     2015   11/1/2014
# 123774      61888  201411020POR   NBA        1     2015   11/2/2014
# 123812      61907  201411050GSW   NBA        0     2015   11/5/2014
# 123858      61930  201411080HOU   NBA        1     2015   11/8/2014
# ...           ...           ...   ...      ...      ...         ...
# 126301      63151  201505270GSW   NBA        0     2015   5/27/2015
# 126303      63152  201506040GSW   NBA        0     2015    6/4/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 123716           1            0     GSW  Warriors   95  1590.80  1602.86
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
sprs = df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)]

# %%
sprs.groupby(['year_id', 'game_result'])['game_id'].count().to_frame()
# Out:
#                      game_id
# year_id game_result
# 2011    L                 25
#         W                 63
# 2012    L                 20
#         W                 60
# 2013    L                 30
#         W                 73
# 2014    L                 27
#         W                 78
# 2015    L                 31
#         W                 58

# %%
sprs.groupby(['year_id', 'game_result'])['game_id'].count().to_frame()
# Out:
#                      game_id
# year_id game_result
# 2011    L                 25
#         W                 63
# 2012    L                 20
#         W                 60
# 2013    L                 30
#         W                 73
# 2014    L                 27
#         W                 78
# 2015    L                 31
#         W                 58

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba = df.copy()

# %%
nba.equals(df)
# Out:
# True

# %%
print('hello \
world!')
# Out:
# hello world!

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.ndim
# Out:
# 2

# %%
nba["difference"] = df.pts - df.opp_pts

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba['difference'].max()
# Out:
# 68

# %%
nba.difference.max()
# Out:
# 68

# %%
renamed_nba = nba.rename(
    columns={"game_result": "result", "game_location": "location"}
)

renamed_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %%
renamed_nba = nba.rename(
    columns={"result": "game_result", "location": "game_location"}, inplace = True)

# %%
renamed_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
nba.rename(
    columns={"game_result": "result", "game_location": "location"}, inplace = True
)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n location result  forecast notes  \
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]
elo_columns
# Out:
# ['elo_i', 'elo_n', 'opp_elo_i', 'opp_elo_n']

# %%
nba.drop(elo_columns, axis = 1, inplace = True)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.shape
# Out:
# (126314, 20)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  object
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
nba['date_game'] = pd.to_datetime(nba["date_game"])

# %%
type(nba)
# Out:
# pandas.core.frame.DataFrame

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  object
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
nba["location"].nunique()
# Out:
# 3

# %%
nba["location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %%
nba['notes'].nunique()
# Out:
# 231

# %%
nba['notes'].value_counts()
# Out:
# at New York NY                440
# at Philadelphia PA            256
# at Norfolk VA                 240
# at Boston MA                  232
# at Greensboro NC              218
#                              ...
# at Winnipeg Canada              2
# at Lincoln HS in Phila. PA      2
# at St. Paul MN                  2
# at Bangor ME                    2
# at The O2, London, England      2
# Name: notes, Length: 231, dtype: int64

# %%
nba["location"] = pd.Categorical(nba["location"])

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba['location'].dtypes
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba['result'].dtypes
# Out:
# dtype('O')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  category
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
rows_without_missing_data = nba.dropna()

# %%
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_without_missing_columns = nba.dropna(axis=1)
data_without_missing_columns
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947 1946-11-01           1
# 1          1  194611010TRH   NBA        1     1947 1946-11-01           1
# 2          2  194611020CHS   NBA        0     1947 1946-11-02           1
# 3          2  194611020CHS   NBA        1     1947 1946-11-02           2
# 4          3  194611020DTF   NBA        0     1947 1946-11-02           1
#
#    is_playoffs team_id  fran_id  pts  win_equiv opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies   66      40.29    NYK    Knicks       68
# 1            0     NYK   Knicks   68      41.71    TRH   Huskies       66
# 2            0     CHS    Stags   63      42.01    NYK    Knicks       47
# 3            0     NYK   Knicks   47      40.69    CHS     Stags       63
# 4            0     DTF  Falcons   33      38.86    WSC  Capitols       50
#
#   location result  forecast notes  difference
# ...

# %%
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)

# %%
data_with_default_notes.describe(include = 'O')
# Out:
#              game_id   lg_id team_id fran_id  opp_id opp_fran  result  \
# count         126314  126314  126314  126314  126314   126314  126314
# unique         63157       2     104      53     104       53       2
# top     194611010TRH     NBA     BOS  Lakers     BOS   Lakers       L
# freq               2  118016    5997    6024    5997     6024   63157
#
#                   notes
# count            126314
# unique              232
# top     no notes at all
# freq             120890

# %%
data_with_default_notes['notes'].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#        win_equiv    opp_pts   forecast  difference
# count  126314.00  126314.00  126314.00   126314.00
# mean       41.71     102.73       0.50        0.00
# std        10.63      14.81       0.22       13.37
# min        10.15       0.00       0.02      -68.00
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       location result  forecast                           notes  difference
# 26684        A      L      0.33  at Richmond VA; forfeit to VIR          -2

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["result"] != 'L')].empty
# Out:
# True

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'L')].empty
# Out:
# False

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False)

# %%
all_city_data2
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_datahps = city_data.drop('Toronto')

# %%
city_datahps
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
all_city_datagbng = pd.merge(city_datahps, further_city_data, left_index = True,
                             right_index=True, how='outer')

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_datahps
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
all_city_datagbng
# Out:
#            revenue_x  employee_count_x  revenue_y  employee_count_y
# Amsterdam     4200.0               5.0        NaN               NaN
# Barcelona        NaN               NaN     3400.0               2.0
# New York         NaN               NaN     7000.0               2.0
# Tokyo         6500.0               8.0        NaN               NaN

# %%
all_city_datagbng.rename(columns={'revenue_x' : 'revenue_a',
                                  'employee_count_x' : 'employe_b'}, inplace = True)

# %%
all_city_datagbng
# Out:
#            revenue_a  employe_b  revenue_y  employee_count_y
# Amsterdam     4200.0        5.0        NaN               NaN
# Barcelona        NaN        NaN     3400.0               2.0
# New York         NaN        NaN     7000.0               2.0
# Tokyo         6500.0        8.0        NaN               NaN

# %%
city_datahps
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
citygbng = pd.merge(city_datahps, further_city_data, how='outer')

# %%
citygbng
# Out:
#    revenue  employee_count
# 0     4200             5.0
# 1     6500             8.0
# 2     7000             2.0
# 3     3400             2.0

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)

city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
countries = pd.DataFrame({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
}, index=["Holland", "Japan", "Canada"])

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
citiescitie
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# ## Visualisasi Data

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba['fran_id']
# Out:
# 0           Huskies
# 1            Knicks
# 2             Stags
# 3            Knicks
# 4           Falcons
#             ...
# 126309    Cavaliers
# 126310     Warriors
# 126311    Cavaliers
# 126312    Cavaliers
# 126313     Warriors
# Name: fran_id, Length: 126314, dtype: object

# %%
nba["fran_id"].value_counts().head(20).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].head()
# Out:
# 0    Huskies
# 1     Knicks
# 2      Stags
# 3     Knicks
# 4    Falcons
# Name: fran_id, dtype: object

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64
