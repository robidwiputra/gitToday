# %% [markdown]
# # Python for Data Science // S.10 // Inferential Statistics // PYTN-KS09
# ---

# %% [markdown]
# ## Import Modules

# %%
# for inline plots in jupyter
# %matplotlib inline
# import matplotlib
import matplotlib.pyplot as plt
# for latex equations
from IPython.display import Math, Latex
# for displaying images
from IPython.core.display import Image

# %%
# import seaborn
import seaborn as sns
# settings for seaborn plotting style
sns.set(color_codes=True)
# settings for seaborn plot sizes
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# ## Distribusi Frekuensi

# %%
from scipy.stats import uniform

# %%
# random numbers from uniform distribution
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# %%
# plotting uniform distribution

ax = sns.distplot(data_uniform,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Uniform Distribution ', ylabel='Frequency')
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import norm
# generate random numbers from N(0,1)
data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
# plotting distribusi normal
ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import gamma
data_gamma = gamma.rvs(a=5, size=10000)

# %%
# plotting gamma distribution
ax = sns.distplot(data_gamma,
                  kde=True,
                  bins=100,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Gamma Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Gamma Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1,loc=0,size=1000)

# %%
# plotting exponential distribution
ax = sns.distplot(data_expon,
                  kde=True,
                  bins=100,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
# plotting poisson distributon
ax = sns.distplot(data_poisson,
bins=30,
kde=False,
 color='skyblue',
hist_kws={'linewidth': 15, 'alpha':1})
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)

# %%
# plotting binomial distribution
ax = sns.distplot(data_binom,
kde=False,
color='skyblue',
hist_kws={'linewidth': 15, 'alpha':1})
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.6)

# %%
# plotting bernoulli distribution
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'Bernoulli Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ## Confidence Interval

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
# mengganti 1 dan 0 dengan 'pria' atau 'wanita' di kolom baru 'Sex1'
df['Sex1'] = df.sex.replace({1: 'Male', 0: 'Female'})

# %%
# membuat dataframe hanya dua kolom yang dibutukan
dx = df[['target', 'Sex1']].dropna()

# %%
pd.crosstab(dx.target, dx.Sex1)
# Out:
# Sex1    Female  Male
# target
# 0           86   413
# 1          226   300

# %%
# menghitung proporsi pendudukan wanita menderita penyaki
p_fm = 226 / (86+226)
p_fm
# Out:
# 0.7243589743589743

# %%
# jumlah populasi wanita
n = 86 + 226
n
# Out:
# 312

# %%
# menghitung standard error
se_female = np.sqrt(p_fm * (1 - p_fm) / n)
se_female
# Out:
# 0.02529714756803247

# %%
# membuat confidence interval dengan z = 1.96 (CI 95%)
z_score = 1.96
lcb = p_fm - z_score * se_female #lower limit of the CI
ucb = p_fm + z_score * se_female #Upper limit of the CI
lcb, ucb
# Out:
# (0.6747765651256307, 0.773941383592318)

# %%
print(lcb, ucb)
# Out:
# 0.6747765651256307 0.773941383592318

# %%
# menghitung confidence interval menggunakan 'statsmodels'
import statsmodels.api as sm
sm.stats.proportion_confint(n * p_fm, n)
# Out:
# (0.6747774762140357, 0.773940472503913)

# %% [markdown]
# ## Calculation of CI of mean

# %%
dfn = df.groupby('Sex1').agg({'chol' : [np.mean, np.std, np.size]})
dfn
# Out:
#               chol
#               mean        std size
# Sex1
# Female  261.455128  64.466781  312
# Male    239.237027  43.155535  713

# %%
dfn.columns
# Out:
# MultiIndex([('chol', 'mean'),
#             ('chol',  'std'),
#             ('chol', 'size')],
#            )

# %%
sd_ = dfn.loc['Female', ('chol',  'std')]

# %%
sd_
# Out:
# 64.46678079217996

# %%
mean_fe = dfn.loc['Female', ('chol',  'mean')]
mean_fe
# Out:
# 261.45512820512823

# %%
# menghitung standard error of the mean
se = sd_ / np.sqrt(n)

# %%
se
# Out:
# 3.6497127678109655

# %%
# membuat confidence interval dengan z = 1.96 (CI 95%)
lcb = mean_fe - z_score * se #lower limit of the CI
ucb = mean_fe + z_score * se #Upper limit of the CI
print("Nilai CI adalah", lcb, ucb)
# Out:
# Nilai CI adalah 254.30169118021874 268.6085652300377

# %%
se_female
# Out:
# 0.02529714756803247

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target    Sex1
# 0         2   2     3       0    Male
# 1         0   0     3       0    Male
# 2         0   0     3       0    Male
# 3         2   1     3       0    Male
# 4         1   3     2       0  Female
# ...     ...  ..   ...     ...     ...
# 1020      2   0     2       1    Male
# 1021      1   1     3       0    Male
# 1022      1   1     2       0    Male
# 1023      2   0     2       1  Female
# 1024      1   1     3       0    Male
#
# [1025 rows x 15 columns]

# %%
n
# Out:
# 312

# %% [markdown]
# ## Other Example of Confidence Intervals

# %%
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import numpy as np
import random
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(rc={'figure.figsize':(13, 7.5)})
sns.set_context('talk')

# %%
np.random.seed(42)
normal_distribution_us_male_mass_pounds = np.random.normal(loc=181, scale=24, size=6000)
normal_distribution_us_female_mass_pounds = np.random.normal(loc=132, scale=22, size=6500)
all_mass_values = np.concatenate((normal_distribution_us_male_mass_pounds, normal_distribution_us_female_mass_pounds), axis=0)
df_ppl_mass = pd.DataFrame(data={'us_people_mass_pounds': all_mass_values})

# %%
df_ppl_mass.head()
# Out:
#    us_people_mass_pounds
# 0             192.921140
# 1             177.681657
# 2             196.544525
# 3             217.552717
# 4             175.380319

# %%
df_ppl_mass.shape
# Out:
# (12500, 1)

# %%
# plotting histogram di kolom us_people_mass_pounds\
sns.distplot(df_ppl_mass['us_people_mass_pounds'], color="darkslategrey")
plt.xlabel("mass [pounds]", labelpad=14)
plt.ylabel("probability of occurence", labelpad=14)
plt.title("Distribution of Mass of People in U.S.", y=1.015, fontsize=20);
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Calculation Population Mean
pop_mean_mass = df_ppl_mass['us_people_mass_pounds'].mean()
pop_mean_mass
# Out:
# 155.4232805942338

# %%
# Calculate Population Standard Deviation
pop_std_dev_mass = df_ppl_mass['us_people_mass_pounds'].std()
pop_std_dev_mass
# Out:
# 33.585190883958624

# %%
# menghitung rata-rata sampel, dengan 300 sampel tersusun atas 25 nilai acak
sample_means = []
n = 25
for sample in range(0, 300):
    # random sampling done with replacement
    sample_values = np.random.choice(a=df_ppl_mass['us_people_mass_pounds'], size=n)    
    sample_mean = np.mean(sample_values)
    sample_means.append(sample_mean)

# %%
# View Distribution of Sample Means (Otherwise Called Sampling Distribution)
sns.distplot(sample_means)
plt.title("Distribution of Sample Means ($n=25$) of People's Mass in Pounds", y=1.015, fontsize=20)
plt.xlabel("sample mean mass [pounds]", labelpad=14)
plt.ylabel("frequency of occurence", labelpad=14);
# Out:
# C:\Users\ACER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Calculate Sampling Distribution (n=25) Summary Statistics

# %%
# Calculate Median of Sample Means
median_of_sample_means = np.mean(sample_means)
median_of_sample_means
# Out:
# 155.12418330193915

# %%
# Calculate Mean of Sample Means
mean_of_sample_means = np.mean(sample_means)
mean_of_sample_means
# Out:
# 155.12418330193915

# %%
# nilai sample means ~ population means
pop_mean_mass
# Out:
# 155.4232805942338

# %%
# Calculate Standard Deviation of Sample Means
std_dev_of_sample_means = np.std(sample_means)
std_dev_of_sample_means
# Out:
# 6.734407481483423

# %%
# qquation for Standard Deviation of Sampling Distribution
standard_error = pop_std_dev_mass/np.sqrt(n)
standard_error
# Out:
# 6.717038176791725

# %% [markdown]
# ## Critizal Z-scores

# %%
# menghitung area pada distribusi normal untuk z = 1.96
stats.norm.cdf(1.96)
# Out:
# 0.9750021048517795

# %%
# menghitung ekor 0.025
tail = 1 - stats.norm.cdf(1.96)
tail
# Out:
# 0.024997895148220484

# %%
stats.norm.cdf(1.96) + tail
# Out:
# 1.0

# %%
# The area under the curve between the z-critical scores is approximately 0.95
1 - (tail * 2)
# Out:
# 0.950004209703559

# %%
# menghitung batas untuk area 95% mean sampel dari mean populasi
lower_95_perc_bound = mean_of_sample_means - 1.96*standard_error
lower_95_perc_bound
# Out:
# 141.95878847542738

# %%
upper_95_perc_bound = mean_of_sample_means + 1.96*standard_error
upper_95_perc_bound
# Out:
# 168.28957812845093

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace(np.min(sample_means), np.max(sample_means), 10000)
plt.plot(pos, kde(pos), color='teal')
shade = np.linspace(lower_95_perc_bound, upper_95_perc_bound, 300)
plt.fill_between(shade, kde(shade), alpha=0.45, color='teal',)
plt.text(x=154, y=.01, horizontalalignment='center', fontsize=17, 
         s="95% of sample means fall within\nthis shaded area of plus or minus\n1.96 z-scores from the mean", 
         bbox=dict(facecolor='whitesmoke', boxstyle="round, pad=0.1"))
plt.title("Distribution of Sample Means ($n=25$) of People's Mass in Pounds", y=1.015, fontsize=20)
plt.xlabel("sample mean mass [pounds]", labelpad=14)
plt.ylabel("frequency of occurence", labelpad=14);

# %%
standard_error
# Out:
# 6.717038176791725

# %% [markdown]
# ## Hypothesis Testing

# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
n = 1018
pnull = .52
phat = .56

# %%
sm.stats.proportions_ztest(phat * n, n, pnull, alternative='larger')
# Out:
# (2.571067795759113, 0.005069273865860533)

# %% [markdown]
# ### Difference in Population Means

# %%
url = "https://raw.githubusercontent.com/kshedden/statswpy/master/NHANES/merged/nhanes_2015_2016.csv"
da = pd.read_csv(url)
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
females = da[da["RIAGENDR"] == 2]
male = da[da["RIAGENDR"] == 1]

# %%
da[['RIAGENDR']]
# Out:
#       RIAGENDR
# 0            1
# 1            1
# 2            1
# 3            2
# 4            2
# ...        ...
# 5730         2
# 5731         1
# 5732         2
# 5733         1
# 5734         2
#
# [5735 rows x 1 columns]

# %%
females
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# 5     83737     2.0     2.0     NaN       2         2        72         1
# 7     83742     1.0     NaN     1.0       2         2        32         1
# 12    83752     1.0     NaN     2.0       1         2        30         2
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5724  93682     NaN     NaN     NaN       2         2        41         5
# 5727  93689     2.0     1.0     NaN       2         2        69         1
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 3          1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4          1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
# 5          2.0       2.0  ...   122.0    58.0   64.4  150.0    28.6    34.4
# 7          2.0       4.0  ...   114.0    70.0   64.5  151.3    28.2    34.1
# 12         1.0       4.0  ...   104.0    50.0   71.2  163.6    26.6    37.3
# ...        ...       ...  ...     ...     ...    ...    ...     ...     ...
# 5724       1.0       5.0  ...   122.0    84.0   58.2  166.9    20.9    37.1
# 5727       1.0       1.0  ...   166.0    64.0   64.8  151.9    28.1    32.2
# 5730       1.0       3.0  ...   112.0    46.0   59.1  165.8    21.5    38.2
# 5732       1.0       4.0  ...   146.0    58.0   71.7  152.2    31.0    31.3
# 5734       1.0       5.0  ...   114.0    68.0   58.3  165.0    21.4    38.2
#
#       BMXARML  BMXARMC  BMXWAIST  HIQ210
# 3        37.7     38.3     110.1     2.0
# 4        36.0     27.2      80.4     2.0
# 5        33.5     31.4      92.9     NaN
# 7        33.1     31.5      93.3     2.0
# 12       35.7     31.0      90.7     2.0
# ...       ...      ...       ...     ...
# 5724     35.3     26.9      80.8     2.0
# 5727     32.6     28.7     101.1     2.0
# 5730     37.0     29.5      95.0     2.0
# 5732     37.5     28.8       NaN     2.0
# 5734     33.5     26.2      72.5     2.0
#
# [2976 rows x 28 columns]

# %%
n1 = len(females)
mu1 = females["BMXBMI"].mean()
sd1 = females["BMXBMI"].std()

(n1, mu1, sd1)
# Out:
# (2976, 29.939945652173996, 7.75331880954568)

# %%
n2 = len(male)
mu2 = male["BMXBMI"].mean()
sd2 = male["BMXBMI"].std()

(n2, mu2, sd2)
# Out:
# (2759, 28.778072111846985, 6.252567616801485)

# %%
sm.stats.ztest(females["BMXBMI"].dropna(), male["BMXBMI"].dropna(),alternative='two-sided')
# Out:
# (6.1755933531383205, 6.591544431126401e-10)

# %%
plt.figure(figsize=(7,4))
plt.title("Female BMI histogram",fontsize=16)
plt.hist(females["BMXBMI"].dropna(),edgecolor='k',color='pink',bins=25)
plt.show()

plt.figure(figsize=(7,4))
plt.title("Male BMI histogram",fontsize=16)
plt.hist(male["BMXBMI"].dropna(),edgecolor='k',color='blue',bins=25)
plt.show()
